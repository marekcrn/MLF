# %% [markdown]
# <a href="https://colab.research.google.com/github/marekcrn/MLF/blob/main/Lab5/lab5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MPA-MLF, Lab 5 - Feedforward Neural Networks

# %% [markdown]
# These exercises are focused on dealing with neural networks. It is strongly recommended to use google collab for these pc labs. Why? Google collab offers a free GPU capacity to train machine learning models. Training NN on GPU can drastically speed up the training process. You can turn on the GPU accelerator in: Runtime -> Change runtime type -> GPU,

# %% [markdown]
# ## The basic terminology

# %% [markdown]
# ### Neural Networks

# %% [markdown]
# Think of a neural network as a complex web of neurons (or nodes) that are interconnected to process information, similar to how the human brain works. Each neuron in this network can receive inputs, process them, and pass on the output to other neurons. The goal of a neural network is to transform the inputs (e.g., images, texts, numbers) into a desired output (e.g., identifying what's in an image, translating text, etc.).

# %% [markdown]
# ![title](https://github.com/MPA-MLF/Exercises/blob/main/Lab_05/img/network.png?raw=1)

# %% [markdown]
# ### Layers

# %% [markdown]
# A neural network is made up of layers: the input layer (where the data enters the network), one or more hidden layers (where most of the processing happens), and the output layer (where the final prediction is made). You can think of each layer as a filter that increasingly refines the information as it passes through the network. In our case, we will discuss feedforward, fully-connected neural networks. Fully connected means that every neuron in layer *n* is connected by a weighted connection with all neurons in the layers *n+1*. Feedforward means that data are passed in one direction only, there are no reccurent connections (feedback loops) exist.

# %% [markdown]
# ![title](https://github.com/MPA-MLF/Exercises/blob/main/Lab_05/img/Neural_network.png?raw=1)

# %% [markdown]
# ### Neuron

# %% [markdown]
# A neuron, or node, is the basic unit of a neural network. It receives input, applies a weight (significance) to that input, adds a bias (a constant value to ensure the neuron activates correctly), and then uses an activation function to determine whether and how strongly to pass its signal to the next layer. Each neuron contributes to the network's ability to make accurate predictions or decisions.|

# %% [markdown]
# ![title](https://github.com/MPA-MLF/Exercises/blob/main/Lab_05/img/neuron.png?raw=1)

# %% [markdown]
# ### Neuron in the input layer

# %% [markdown]
# In the input layer the input neurons are composed of identity only, that means everying that comes to the input comes directly to the output

# %% [markdown]
# ### Training

# %% [markdown]
# Training a neural network involves feeding it with data for which the correct output is known, allowing the network to adjust its weights and biases to minimize the difference between its predictions and the actual truths. This process is repeated numerous times with many data examples.

# %% [markdown]
# ### Loss Function

# %% [markdown]
# A loss function measures how well the neural network is performing, meaning how close or far its predictions are from the actual values. The goal of training is to minimize this loss, or error, making the network's predictions as accurate as possible.

# %% [markdown]
# ## Exercise 1 - XOR problem

# %% [markdown]
# During the last lecture, we saw that the single perceptron model with a step function could be used only for solving linearly-separable classification problems. Because of that, a single perceptron can not be trained to be able to behave like an XOR gate. To approximate the XOR gate using a neural network, we need to use the following structure:

# %% [markdown]
# ![nn.png](data:image/png;base64,...)

# %% [markdown]
# The above structure contains three layers: two neurons in the input layer (blue), two in the hidden layer and one in the output layer (yellow). The input layer represents the identity functions (the outputs are equal to the inputs)

# %% [markdown]
# We will use *Keras* API to build and train our neural network. Keras is an open-source neural network library written in Python. It is designed to enable fast experimentation with deep neural networks and provides a high-level API for building and training neural networks.

# %% [markdown]
# ### 0. First import libraries

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. prepare data

# %% [markdown]
# In this part, the task would be to prepade our dataset, basically it is the logic table for *XOR* function

# %%
X = [[0, 0], [0, 1], [1, 0], [1, 1]]
y = [0, 1, 1, 0]

# %% [markdown]
# ### 2. Creating the model

# %% [markdown]
# To create a model of NN that is in the picture above, run the following cell

# %%
model = Sequential()
model.add(InputLayer(input_shape=(2)))      # input
model.add(Dense(2, activation='sigmoid'))   # hidden layer
model.add(Dense(1, activation='sigmoid'))   # output

# %% [markdown]
# **Sequential** is a model type used in Keras for building feedforward neural networks. It is called "sequential" because the layers are stacked sequentially on top of each other, and the output of one layer is passed as input to the next layer.
#
# To create a sequential model, instantiate a Sequential object and then add layers to it using the **add()** method. There are many layers that Keras offers. We will use *Dense layer*
#
# **Dense layer** represents a fully connected layer, which means that every neuron in the layer is connected to every neuron in the previous layer. In each layer, we will specify an activation function and the number of neurons that layer contains. The input layer is not defined as a dense layer, but instead of that, we will specify the *input_dim* parameter in the layer that follows the input layer. *input_dim* parameter specifies the number of neurons in the input layer

# %% [markdown]
# ### 3. Compile the model

# %% [markdown]
# To compile yor model run:

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %% [markdown]
# **keras.complile()** is used to configure the learning process before training the model.
# We need to specify 3 parameters:
# - *loss*, *optimizer* and *metrics*
#
# - as our loss function (error function/objective function), we will choose *binary_crossentropy* - loss function often used for binary classification
#
# - *optimizer* is optimization algorithm used for optimizing weights in our training process, we will choose *stochastic gradient descent*
#
# - *metrics* is metric user for model evaluation

# %% [markdown]
# ### 4. Model training

# %% [markdown]
# In the lecture, we talked about training the Multi-layer perceptron. The training process consists of the following steps:
#
# 1. Weight initialization
# 2. Forward Propagation
# 3. Compute Loss
# 4. Backpropagation
# 5. Update Weights
# 6. Repeat 2->6 until maximum epochs are reached
#
# When training a machine learning model, the training data is usually divided into batches (parts), and the model updates its weights after processing each batch. The batch size determines how many training examples are included in each batch.
#
# For example, we have 10,000 training examples and a batch size of 100. In this case, the training data would be divided into 100 batches of 100 examples each. During training, the model would process each batch, calculate the loss or error, and update its weights based on the average of the errors in that batch. In other words, if we batch equal to 1. we will update the weights 10 000 times. If we have batch size == 100, we will update the weights only 100 times

# %% [markdown]
# To train your model, run the following line of the code:

# %%
history = model.fit(X, y, epochs=2000, batch_size=1, verbose=0)

# %% [markdown]
# the method **.fit()**, is used to train the model. We can see that it takes several input parameters:
#  - *X* - input data
#  - *y* - label for the input data
#  - *epochs* number of training epochs (iterations)
#  - *batch_size* - number of samples in each batch
#  - *verbose* - set verbose parameter to see the progress of loss and metrics during the training epochs
#
# These are not the only parameters the .fit() method can take. Check official documentation: https://keras.io/api/models/model_training_apis/
#
# We will set the output of our .fit() function to variable *history*, where the loss and other metrics defined above in the .compile() function during the training are saved.

# %% [markdown]
# ### 5. Model evaluation

# %% [markdown]
# Out training process is finished. To evaluate the performance of our model on test data, tun the following cell of the code:

# %%
loss, accuracy = model.evaluate(X, y, verbose=0)
print('Accuracy: {:.2f}'.format(accuracy*100))
# Out:
# Accuracy: 100.00

# %% [markdown]
# ### 6. Model predictions

# %%
for id_x, data_sample in enumerate(X):
  prediction = model.predict([data_sample])
  print(f"Data sample is {data_sample}, prediction from model {prediction}, ground_truth {y[id_x]}")
# Out:
# 1/1 [==============================] - 0s 78ms/step
# Data sample is [0, 0], prediction from model [[0.02811116]], ground_truth 0
# 1/1 [==============================] - 0s 30ms/step
# Data sample is [0, 1], prediction from model [[0.9586789]], ground_truth 1
# 1/1 [==============================] - 0s 28ms/step
# Data sample is [1, 0], prediction from model [[0.95866585]], ground_truth 1
# 1/1 [==============================] - 0s 31ms/step
# Data sample is [1, 1], prediction from model [[0.04154131]], ground_truth 0

# %% [markdown]
# ### 7. Display loss function during the training process and acuracy

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.xlabel('n epochs')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %% [markdown]
# ### TASK:
#
# In this part of the exercise, the task would be to play around with the code above to see the influence of hyperparameters.
#
# As we know from the lecture, neural networks contain two types of parameters:
#   1. **Learnable parameters** - *weights* and *biases*. these parameters are adjusted in the training process.
#   2. **Non-learnable parameters (hyperparameters)** - learning_rate, number_of_neurons, number_of_layers, number_of_epochs, type of activation functions in the neurons.., basically any user-defined setting is considered to be hyperparameter
#
#
# Change the following parameters:
# - number of epochs
# - learning_rate
# - activation functions in layers,
# - batch_size,
# - verbose,
# - number of neurons in the hidden layer
#
# Moreover, see the influence on the training process and results.
#
# **Note: Every time we change some hyper-parameters, do not forget to compile the model, to initialize the learnable parameters again**

# %% [markdown]
# ## Exercise 2 - Congressional Voting Data
#
# In the attached dataset, results from congressional voting can be found. Your task is to train a model that can recognize that the politician is *republican* or *democrat* based on voting results. We would follow the general machine learning steps that were described in the lecture.

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### 1. Loading dataset

# %% [markdown]
# **First mount your google drive to google colab file.**

# %%
path_to_dataset = '/content/drive/MyDrive/voting_complete.csv' # change the PATH
pd_dataset = pd.read_csv(path_to_dataset)

# %%
pd_dataset
# Out:
#      Unnamed: 0  Class Name handicapped-infants water-project-cost-sharing  \
# 0             0  republican                   n                          y
# 1             1  republican                   n                          y
# 2             2    democrat                   ?                          y
# 3             3    democrat                   n                          y
# 4             4    democrat                   y                          y
# ..          ...         ...                 ...                        ...
# 430         430  republican                   n                          n
# 431         431    democrat                   n                          n
# 432         432  republican                   n                          ?
# 433         433  republican                   n                          n
# 434         434  republican                   n                          y
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                   n                    y               y
# 1                                   n                    y               y
# 2                                   y                    ?               y
# 3                                   y                    n               ?
# 4                                   y                    n               y
# ..                                ...                  ...             ...
# 430                                 y                    y               y
# 431                                 y                    n               n
# 432                                 n                    y               y
# 433                                 n                    y               y
# 434                                 n                    y               y
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 0                             y                       n
# 1                             y                       n
# 2                             y                       n
# 3                             y                       n
# 4                             y                       n
# ..                          ...                     ...
# 430                           y                       n
# 431                           n                       y
# 432                           y                       n
# 433                           y                       ?
# 434                           y                       n
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 0                           n          n           y
# 1                           n          n           n
# 2                           n          n           n
# 3                           n          n           n
# 4                           n          n           n
# ..                        ...        ...         ...
# 430                         n          y           y
# 431                         y          y           y
# 432                         n          n           n
# 433                         ?          ?           ?
# 434                         n          n           y
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                              ?                  y                      y
# 1                              n                  y                      y
# 2                              y                  n                      y
# 3                              y                  n                      y
# 4                              y                  ?                      y
# ..                           ...                ...                    ...
# 430                            n                  y                      y
# 431                            n                  n                      n
# 432                            y                  y                      y
# 433                            n                  y                      y
# 434                            n                  y                      y
#
#     crime duty-free-exports export-administration-act-south-africa
# 0       y                 n                                      y
# 1       y                 n                                      ?
# 2       y                 n                                      n
# 3       n                 n                                      y
# 4       y                 y                                      y
# ..    ...               ...                                    ...
# 430     y                 n                                      y
# 431     n                 n                                      y
# 432     y                 n                                      y
# 433     y                 n                                      y
# 434     y                 ?                                      n
#
# [435 rows x 18 columns]

# %% [markdown]
# ### 2. Train/Test Split

# %% [markdown]
# Fistlty we need to split our dataset into train and test. We will use 80% of dataset as our trainset and 20% od dataset as our testset. You can use functions included in *keras*, *scikit-learn*, or you can write your own:

# %%
# define a function for train and test split

def train_test_split(pd_data: pd.DataFrame, test_ratio: float = 0.2) -> tuple:
    pd_dataset = pd_data.copy()
    pd_dataset = pd_dataset[pd_dataset.columns[1:]]
    index = np.arange(len(pd_dataset))
    index = np.random.permutation(index)
    train_ammount = int(len(index)*test_ratio)
    train_ids = index[train_ammount:]
    test_ids = index[:train_ammount]

    train_dataset = pd_dataset[pd_dataset.index.isin(train_ids)].reset_index()
    test_dataset = pd_dataset[pd_dataset.index.isin(test_ids)].reset_index()

    train_dataset = train_dataset[train_dataset.columns[1:]]
    test_dataset = test_dataset[test_dataset.columns[1:]]

    return train_dataset[train_dataset.columns[1:]], train_dataset[train_dataset.columns[0]], test_dataset[test_dataset.columns[1:]], test_dataset[test_dataset.columns[0]]

# %%
x_train, y_train, x_test, y_test = train_test_split(pd_dataset)

# %% [markdown]
# ### 3. Data examination

# %% [markdown]
# The task would be to examine the dataset. Check:
#
# 1. Is it a classification of regression task?
# 2. How many data samples do we have?
# 3. How many features do we have?
# 4. What data types do we have in our dataset?
# 5. Are there any missing values?
# 6. How many labels do we have?

# %%
x_train
# Out:
#     handicapped-infants water-project-cost-sharing  \
# 0                     n                          y
# 1                     n                          y
# 2                     ?                          y
# 3                     y                          y
# 4                     n                          y
# ..                  ...                        ...
# 343                   y                          n
# 344                   n                          n
# 345                   n                          ?
# 346                   n                          n
# 347                   n                          y
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                   n                    y               y
# 1                                   n                    y               y
# 2                                   y                    ?               y
# 3                                   y                    n               y
# 4                                   y                    n               y
# ..                                ...                  ...             ...
# 343                                 y                    n               ?
# 344                                 y                    n               n
# 345                                 n                    y               y
# 346                                 n                    y               y
# 347                                 n                    y               y
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 0                             y                       n
# 1                             y                       n
# 2                             y                       n
# 3                             y                       n
# 4                             y                       n
# ..                          ...                     ...
# 343                           n                       y
# 344                           n                       y
# 345                           y                       n
# 346                           y                       ?
# 347                           y                       n
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 0                           n          n           y
# 1                           n          n           n
# 2                           n          n           n
# 3                           n          n           n
# 4                           n          n           n
# ..                        ...        ...         ...
# 343                         y          y           y
# 344                         y          y           y
# 345                         n          n           n
# 346                         ?          ?           ?
# 347                         n          n           y
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                              ?                  y                      y
# 1                              n                  y                      y
# 2                              y                  n                      y
# 3                              y                  ?                      y
# 4                              n                  n                      y
# ..                           ...                ...                    ...
# 343                            n                  y                      n
# 344                            n                  n                      n
# 345                            y                  y                      y
# 346                            n                  y                      y
# 347                            n                  y                      y
#
#     crime duty-free-exports export-administration-act-south-africa
# 0       y                 n                                      y
# 1       y                 n                                      ?
# 2       y                 n                                      n
# 3       y                 y                                      y
# 4       y                 y                                      y
# ..    ...               ...                                    ...
# 343     ?                 y                                      y
# 344     n                 n                                      y
# 345     y                 n                                      y
# 346     y                 n                                      y
# 347     y                 ?                                      n
#
# [348 rows x 16 columns]

# %% [markdown]
# ### 4. Data preprocessing

# %% [markdown]
# When you preprocess your traing data, do not forget that you need to apply the same preprocessing also for your test set. For example: If you decide to delete some columns in your train set, you have to delete the same columns in your test set.

# %% [markdown]
# Possible preprocessing steps (try several and see the influence of your preprocessing on your results)
#  - Replace missing values with any data imputation technique ( for example, the most occurring value in the column), then perform one-hot encoding or label encoding of your data
#  - Consider the missing value to be the third category 'unknown' and then perform one-hot encoding or label encoding
#
# The target value also has to be encoded. This can be done by one-hot encoding or label encoding.

# %%
#WRITE YOUR CODE HERE
x_train.replace(('y', 'n', '?'), (1, 0, np.nan), inplace=True)

x_train = x_train.fillna(x_train.mode().iloc[0])    # replace NaN with most common value
for col in x_train.columns:
  x_train[col] = x_train[col].astype('int')

x_train
# Out:
#      handicapped-infants  water-project-cost-sharing  \
# 0                      0                           1
# 1                      0                           1
# 2                      0                           1
# 3                      1                           1
# 4                      0                           1
# ..                   ...                         ...
# 343                    1                           0
# 344                    0                           0
# 345                    0                           1
# 346                    0                           0
# 347                    0                           1
#
#      adoption-of-the-budget-resolution  physician-fee-freeze  el-salvador-aid  \
# 0                                    0                     1                1
# 1                                    0                     1                1
# 2                                    1                     0                1
# 3                                    1                     0                1
# 4                                    1                     0                1
# ..                                 ...                   ...              ...
# 343                                  1                     0                1
# 344                                  1                     0                0
# 345                                  0                     1                1
# 346                                  0                     1                1
# 347                                  0                     1                1
#
#      religious-groups-in-schools  anti-satellite-test-ban  \
# 0                              1                        0
# 1                              1                        0
# 2                              1                        0
# 3                              1                        0
# 4                              1                        0
# ..                           ...                      ...
# 343                            0                        1
# 344                            0                        1
# 345                            1                        0
# 346                            1                        1
# 347                            1                        0
#
#      aid-to-nicaraguan-contras  mx-missile  immigration  \
# 0                            0           0            1
# 1                            0           0            0
# 2                            0           0            0
# 3                            0           0            0
# 4                            0           0            0
# ..                         ...         ...          ...
# 343                          1           1            1
# 344                          1           1            1
# 345                          0           0            0
# 346                          1           1            0
# 347                          0           0            1
#
#      synfuels-corporation-cutback  education-spending  superfund-right-to-sue  \
# 0                               0                   1                       1
# 1                               0                   1                       1
# 2                               1                   0                       1
# 3                               1                   0                       1
# 4                               0                   0                       1
# ..                            ...                 ...                     ...
# 343                             0                   1                       0
# 344                             0                   0                       0
# 345                             1                   1                       1
# 346                             0                   1                       1
# 347                             0                   1                       1
#
#      crime  duty-free-exports  export-administration-act-south-africa
# 0        1                  0                                       1
# 1        1                  0                                       1
# 2        1                  0                                       0
# 3        1                  1                                       1
# 4        1                  1                                       1
# ..     ...                ...                                     ...
# 343      1                  1                                       1
# 344      0                  0                                       1
# 345      1                  0                                       1
# 346      1                  0                                       1
# 347      1                  0                                       0
#
# [348 rows x 16 columns]

# %%
#WRITE YOUR CODE HERE
y_train = y_train.replace(('republican', 'democrat'), (1, 0))
y_train
# Out:
# 0      1
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 343    0
# 344    0
# 345    1
# 346    1
# 347    1
# Name: Class Name, Length: 348, dtype: int64

# %% [markdown]
# ### 5. Creating the model

# %% [markdown]
# 1. Create your model using alteast one hidden layer.
#
# *hint: do not create too complex models, this is a very simple task, so it would be enought to use just few neurons in the hidden layers*

# %%
# WRITE YOU CODE HERE
model = Sequential()
model.add(Dense(units=8, activation='LeakyReLU', input_dim=16))
model.add(Dense(units=8, activation='LeakyReLU'))
model.add(Dense(units=1, activation='sigmoid'))

# %% [markdown]
# 2. Check what *model.summary()* does

# %%
# WRITE YOU CODE HERE
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_19 (Dense)            (None, 8)                 136
#
#  dense_20 (Dense)            (None, 8)                 72
#
#  dense_21 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 217 (868.00 Byte)
# Trainable params: 217 (868.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# 3. Compile the model, choose a suitable loss function, choose gradient to descend optimizer and specify the learning rate, and choose accuracy as our metric

# %%
# WRITE YOUR CODE HERE
optimizer = tf.keras.optimizers.SGD(learning_rate=0.5)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# 4. Train the model. Specify the number of epochs and batch size. Now is the time to create a validation dataset. Set 20% of dataset to be a validation dataset

# %%
#cWRITE YOUR CODE HERE
history = model.fit(x=x_train, y=y_train, validation_split=0.2, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 1s 25ms/step - loss: 0.4973 - accuracy: 0.7914 - val_loss: 0.4151 - val_accuracy: 0.8143
# Epoch 2/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2105 - accuracy: 0.9209 - val_loss: 0.3535 - val_accuracy: 0.8714
# Epoch 3/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1565 - accuracy: 0.9496 - val_loss: 0.3301 - val_accuracy: 0.8857
# Epoch 4/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1146 - accuracy: 0.9676 - val_loss: 0.3327 - val_accuracy: 0.8714
# Epoch 5/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0955 - accuracy: 0.9712 - val_loss: 0.2546 - val_accuracy: 0.9000
# Epoch 6/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0872 - accuracy: 0.9712 - val_loss: 0.2575 - val_accuracy: 0.9000
# Epoch 7/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0922 - accuracy: 0.9676 - val_loss: 0.2854 - val_accuracy: 0.9000
# Epoch 8/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0755 - accuracy: 0.9712 - val_loss: 0.2700 - val_accuracy: 0.9000
# Epoch 9/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0790 - accuracy: 0.9748 - val_loss: 0.2559 - val_accuracy: 0.9000
# Epoch 10/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0748 - accuracy: 0.9712 - val_loss: 0.2647 - val_accuracy: 0.9000
# Epoch 11/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0713 - accuracy: 0.9748 - val_loss: 0.3671 - val_accuracy: 0.8714
# Epoch 12/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0876 - accuracy: 0.9640 - val_loss: 0.2453 - val_accuracy: 0.9000
# Epoch 13/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0602 - accuracy: 0.9784 - val_loss: 0.2777 - val_accuracy: 0.9143
# Epoch 14/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0622 - accuracy: 0.9712 - val_loss: 0.2395 - val_accuracy: 0.9000
# Epoch 15/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0622 - accuracy: 0.9784 - val_loss: 0.2915 - val_accuracy: 0.9000
# Epoch 16/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0677 - accuracy: 0.9748 - val_loss: 0.2637 - val_accuracy: 0.9143
# Epoch 17/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0486 - accuracy: 0.9748 - val_loss: 0.2826 - val_accuracy: 0.9143
# Epoch 18/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0585 - accuracy: 0.9784 - val_loss: 0.3102 - val_accuracy: 0.9000
# Epoch 19/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0543 - accuracy: 0.9712 - val_loss: 0.2768 - val_accuracy: 0.9000
# Epoch 20/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0519 - accuracy: 0.9748 - val_loss: 0.2643 - val_accuracy: 0.8857
# Epoch 21/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0523 - accuracy: 0.9820 - val_loss: 0.2871 - val_accuracy: 0.9000
# Epoch 22/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0442 - accuracy: 0.9820 - val_loss: 0.4859 - val_accuracy: 0.8571
# Epoch 23/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0623 - accuracy: 0.9784 - val_loss: 0.2750 - val_accuracy: 0.8857
# Epoch 24/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0553 - accuracy: 0.9784 - val_loss: 0.2795 - val_accuracy: 0.9000
# Epoch 25/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0453 - accuracy: 0.9820 - val_loss: 0.2904 - val_accuracy: 0.9000
# Epoch 26/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0579 - accuracy: 0.9748 - val_loss: 0.2832 - val_accuracy: 0.9000
# Epoch 27/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0725 - accuracy: 0.9748 - val_loss: 0.2850 - val_accuracy: 0.8857
# Epoch 28/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0402 - accuracy: 0.9820 - val_loss: 0.3067 - val_accuracy: 0.9000
# Epoch 29/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0442 - accuracy: 0.9820 - val_loss: 0.3146 - val_accuracy: 0.9000
# Epoch 30/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0449 - accuracy: 0.9784 - val_loss: 0.4793 - val_accuracy: 0.8714
# Epoch 31/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0729 - accuracy: 0.9712 - val_loss: 0.3685 - val_accuracy: 0.9000
# Epoch 32/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0421 - accuracy: 0.9820 - val_loss: 0.2947 - val_accuracy: 0.8857
# Epoch 33/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0411 - accuracy: 0.9856 - val_loss: 0.3115 - val_accuracy: 0.9000
# Epoch 34/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0477 - accuracy: 0.9784 - val_loss: 0.3008 - val_accuracy: 0.9000
# Epoch 35/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0408 - accuracy: 0.9820 - val_loss: 0.2898 - val_accuracy: 0.9143
# Epoch 36/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0421 - accuracy: 0.9856 - val_loss: 0.3729 - val_accuracy: 0.9000
# Epoch 37/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0517 - accuracy: 0.9712 - val_loss: 0.2877 - val_accuracy: 0.9000
# Epoch 38/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0771 - accuracy: 0.9640 - val_loss: 0.3753 - val_accuracy: 0.9000
# Epoch 39/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0408 - accuracy: 0.9820 - val_loss: 0.2952 - val_accuracy: 0.9000
# Epoch 40/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0342 - accuracy: 0.9892 - val_loss: 0.3367 - val_accuracy: 0.9000
# Epoch 41/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0303 - accuracy: 0.9892 - val_loss: 0.4453 - val_accuracy: 0.9000
# Epoch 42/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0474 - accuracy: 0.9712 - val_loss: 0.4045 - val_accuracy: 0.9000
# Epoch 43/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0420 - accuracy: 0.9820 - val_loss: 0.4404 - val_accuracy: 0.8714
# Epoch 44/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0467 - accuracy: 0.9784 - val_loss: 0.2858 - val_accuracy: 0.8857
# Epoch 45/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0392 - accuracy: 0.9856 - val_loss: 0.3932 - val_accuracy: 0.9000
# Epoch 46/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0445 - accuracy: 0.9784 - val_loss: 0.4046 - val_accuracy: 0.9000
# Epoch 47/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0388 - accuracy: 0.9784 - val_loss: 0.2992 - val_accuracy: 0.9000
# Epoch 48/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0440 - accuracy: 0.9820 - val_loss: 0.3315 - val_accuracy: 0.9000
# Epoch 49/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0421 - accuracy: 0.9820 - val_loss: 0.3157 - val_accuracy: 0.8857
# Epoch 50/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0367 - accuracy: 0.9856 - val_loss: 0.3343 - val_accuracy: 0.9000
# Epoch 51/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0416 - accuracy: 0.9820 - val_loss: 0.3312 - val_accuracy: 0.8857
# Epoch 52/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0439 - accuracy: 0.9820 - val_loss: 0.3132 - val_accuracy: 0.8857
# Epoch 53/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0462 - accuracy: 0.9856 - val_loss: 0.3452 - val_accuracy: 0.9000
# Epoch 54/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0316 - accuracy: 0.9856 - val_loss: 0.3277 - val_accuracy: 0.9143
# Epoch 55/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0358 - accuracy: 0.9856 - val_loss: 0.3606 - val_accuracy: 0.9000
# Epoch 56/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0392 - accuracy: 0.9856 - val_loss: 0.3109 - val_accuracy: 0.8857
# Epoch 57/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0536 - accuracy: 0.9820 - val_loss: 0.3172 - val_accuracy: 0.8857
# Epoch 58/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0308 - accuracy: 0.9820 - val_loss: 0.3297 - val_accuracy: 0.9000
# Epoch 59/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0342 - accuracy: 0.9820 - val_loss: 0.3392 - val_accuracy: 0.9000
# Epoch 60/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0340 - accuracy: 0.9856 - val_loss: 0.3475 - val_accuracy: 0.9000
# Epoch 61/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0267 - accuracy: 0.9892 - val_loss: 0.3356 - val_accuracy: 0.8857
# Epoch 62/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0388 - accuracy: 0.9784 - val_loss: 0.5824 - val_accuracy: 0.9143
# Epoch 63/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0604 - accuracy: 0.9892 - val_loss: 0.3140 - val_accuracy: 0.8857
# Epoch 64/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0287 - accuracy: 0.9856 - val_loss: 0.3321 - val_accuracy: 0.8857
# Epoch 65/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0298 - accuracy: 0.9856 - val_loss: 0.3449 - val_accuracy: 0.9000
# Epoch 66/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0308 - accuracy: 0.9892 - val_loss: 0.3330 - val_accuracy: 0.8857
# Epoch 67/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0384 - accuracy: 0.9820 - val_loss: 0.4336 - val_accuracy: 0.8857
# Epoch 68/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0265 - accuracy: 0.9928 - val_loss: 0.3322 - val_accuracy: 0.9000
# Epoch 69/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0257 - accuracy: 0.9856 - val_loss: 0.3497 - val_accuracy: 0.9143
# Epoch 70/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0350 - accuracy: 0.9892 - val_loss: 0.3742 - val_accuracy: 0.9000
# Epoch 71/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0307 - accuracy: 0.9856 - val_loss: 0.3733 - val_accuracy: 0.8714
# Epoch 72/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0295 - accuracy: 0.9856 - val_loss: 0.3554 - val_accuracy: 0.8857
# Epoch 73/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0277 - accuracy: 0.9892 - val_loss: 0.4165 - val_accuracy: 0.9000
# Epoch 74/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0634 - accuracy: 0.9748 - val_loss: 0.3695 - val_accuracy: 0.9000
# Epoch 75/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0286 - accuracy: 0.9856 - val_loss: 0.3461 - val_accuracy: 0.9000
# Epoch 76/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0292 - accuracy: 0.9856 - val_loss: 0.3428 - val_accuracy: 0.9000
# Epoch 77/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0276 - accuracy: 0.9928 - val_loss: 0.4089 - val_accuracy: 0.8714
# Epoch 78/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0278 - accuracy: 0.9892 - val_loss: 0.3695 - val_accuracy: 0.9000
# Epoch 79/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0270 - accuracy: 0.9856 - val_loss: 0.3455 - val_accuracy: 0.9000
# Epoch 80/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0327 - accuracy: 0.9820 - val_loss: 0.3988 - val_accuracy: 0.8857
# Epoch 81/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0269 - accuracy: 0.9856 - val_loss: 0.4347 - val_accuracy: 0.8714
# Epoch 82/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0277 - accuracy: 0.9856 - val_loss: 0.4480 - val_accuracy: 0.8714
# Epoch 83/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0355 - accuracy: 0.9856 - val_loss: 0.3435 - val_accuracy: 0.9000
# Epoch 84/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0234 - accuracy: 0.9892 - val_loss: 0.3637 - val_accuracy: 0.9000
# Epoch 85/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0275 - accuracy: 0.9856 - val_loss: 0.3727 - val_accuracy: 0.9000
# Epoch 86/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0230 - accuracy: 0.9856 - val_loss: 0.4021 - val_accuracy: 0.9000
# Epoch 87/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0243 - accuracy: 0.9892 - val_loss: 0.3969 - val_accuracy: 0.9000
# Epoch 88/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0351 - accuracy: 0.9892 - val_loss: 0.3423 - val_accuracy: 0.9143
# Epoch 89/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0266 - accuracy: 0.9820 - val_loss: 0.3766 - val_accuracy: 0.9000
# Epoch 90/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0205 - accuracy: 0.9856 - val_loss: 0.3789 - val_accuracy: 0.9143
# Epoch 91/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0268 - accuracy: 0.9856 - val_loss: 0.3817 - val_accuracy: 0.9000
# Epoch 92/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0251 - accuracy: 0.9892 - val_loss: 0.6194 - val_accuracy: 0.8714
# Epoch 93/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0384 - accuracy: 0.9820 - val_loss: 0.4407 - val_accuracy: 0.9000
# Epoch 94/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0264 - accuracy: 0.9820 - val_loss: 0.4270 - val_accuracy: 0.9000
# Epoch 95/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0272 - accuracy: 0.9856 - val_loss: 0.4821 - val_accuracy: 0.8714
# Epoch 96/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0268 - accuracy: 0.9820 - val_loss: 0.5047 - val_accuracy: 0.8571
# Epoch 97/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0244 - accuracy: 0.9856 - val_loss: 0.3820 - val_accuracy: 0.9000
# Epoch 98/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0282 - accuracy: 0.9820 - val_loss: 0.3661 - val_accuracy: 0.9143
# Epoch 99/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0224 - accuracy: 0.9892 - val_loss: 0.3712 - val_accuracy: 0.9000
# Epoch 100/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0216 - accuracy: 0.9856 - val_loss: 0.3717 - val_accuracy: 0.9143

# %% [markdown]
# ### 7. Model Evaluation

# %% [markdown]
# 1. First, apply the same preprocessing you did to train set to test set also

# %%
# WRITE YOUR CODE HERE
x_test.replace(('y', 'n', '?'), (1, 0, np.nan), inplace=True)
y_test = y_test.replace(('republican', 'democrat'), (1, 0))

x_test = x_test.fillna(x_test.mode().iloc[0])    # replace NaN with most common value
for col in x_train.columns:
  x_test[col] = x_test[col].astype('int')

x_test
# Out:
#     handicapped-infants  water-project-cost-sharing  \
# 0                     0                           1
# 1                     0                           1
# 2                     0                           1
# 3                     0                           1
# 4                     1                           0
# ..                  ...                         ...
# 82                    0                           0
# 83                    0                           1
# 84                    1                           1
# 85                    0                           0
# 86                    0                           0
#
#     adoption-of-the-budget-resolution  physician-fee-freeze  el-salvador-aid  \
# 0                                   1                     0                0
# 1                                   0                     1                1
# 2                                   0                     1                1
# 3                                   0                     1                1
# 4                                   1                     0                0
# ..                                ...                   ...              ...
# 82                                  0                     1                1
# 83                                  1                     0                0
# 84                                  1                     0                0
# 85                                  1                     0                0
# 86                                  1                     1                1
#
#     religious-groups-in-schools  anti-satellite-test-ban  \
# 0                             1                        0
# 1                             1                        0
# 2                             1                        0
# 3                             1                        0
# 4                             0                        1
# ..                          ...                      ...
# 82                            1                        0
# 83                            1                        1
# 84                            0                        1
# 85                            0                        1
# 86                            1                        0
#
#     aid-to-nicaraguan-contras  mx-missile  immigration  \
# 0                           0           0            0
# 1                           0           0            0
# 2                           0           0            0
# 3                           0           0            1
# 4                           1           1            0
# ..                        ...         ...          ...
# 82                          0           0            1
# 83                          1           0            1
# 84                          1           1            0
# 85                          1           1            1
# 86                          0           1            1
#
#     synfuels-corporation-cutback  education-spending  superfund-right-to-sue  \
# 0                              1                   0                       1
# 1                              0                   0                       1
# 2                              0                   1                       1
# 3                              0                   1                       1
# 4                              0                   0                       1
# ..                           ...                 ...                     ...
# 82                             0                   1                       1
# 83                             0                   0                       0
# 84                             0                   0                       0
# 85                             0                   0                       1
# 86                             0                   1                       1
#
#     crime  duty-free-exports  export-administration-act-south-africa
# 0       0                  0                                       1
# 1       1                  1                                       1
# 2       1                  0                                       1
# 3       1                  0                                       1
# 4       0                  1                                       1
# ..    ...                ...                                     ...
# 82      1                  0                                       1
# 83      0                  0                                       1
# 84      0                  0                                       1
# 85      0                  1                                       1
# 86      1                  0                                       1
#
# [87 rows x 16 columns]

# %% [markdown]
# 2. Evaluate the model, print final accuracy and loss

# %%
# WRITE YOUR CODE HERE
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
print('Accuracy: {:.2f}'.format(accuracy*100))
# Out:
# Accuracy: 96.55

# %% [markdown]
# 3. Plot loss and validation loss depending on the training epochs into one graph. In another graph, plot accuracy and validation accuracy

# %%
# WRITE YOUR CODE HERE
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score

predictions = np.round(model.predict(x_test, verbose=0))

cm = confusion_matrix(y_test, predictions)

disp = ConfusionMatrixDisplay(cm, display_labels=['democrat', 'republican'])
disp.plot()
print(f"Test passed with F1 score of {np.round(f1_score(y_test, predictions)*100, decimals=2)} %")
# Out:
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7d675ed9eef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Test passed with F1 score of 95.65 %

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.xlabel('n epochs')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')
